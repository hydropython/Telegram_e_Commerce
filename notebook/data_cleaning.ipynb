# %%
import pandas as pd
import pandas as pd
import re
import os
# Load your DataFrame
df = pd.read_csv('../Data/telegram_data_zemen_express.csv')

# %%
df
# Out:
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5334
# 1     Zemen Express®    @ZemenExpress  5333
# 2     Zemen Express®    @ZemenExpress  5332
# 3     Zemen Express®    @ZemenExpress  5330
# 4     Zemen Express®    @ZemenExpress  5328
# ...              ...              ...   ...
# 2632  Zemen Express®    @ZemenExpress  2598
# 2633  Zemen Express®    @ZemenExpress  2597
# 2634  Zemen Express®    @ZemenExpress  2596
# 2635  Zemen Express®    @ZemenExpress  2595
# 2636  Zemen Express®    @ZemenExpress  2593
#
#                                                 Message  \
# 0     💥💥...................................💥💥\n\n🎯Ko...
# 1     💥💥...................................💥💥\n\n🎯Ko...
# 2     💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 3     💥💥...................................💥💥\n\n📌Si...
# 4                                                   NaN
# ...                                                 ...
# 2632  🎯 3pcs Stainless Steel Cake Shovel Cutter Knif...
# 2633  🎯3pcs Isolated Heat Pad \n🔰ሙቀትን መቋቋም የሚችል ትኩስ ...
# 2634  🎯 የእንጀራ እና የዳቦ ማቅረቢያ\n\nዋጋ፦  💰🏷  2500 ብር \n   ...
# 2635  🎯 Adjustable Base For Washing amachine & Refri...
# 2636  🎯 Adjustable Base For Washing amachine & Refri...
#
#                            Date                     Media Path
# 0     2024-09-26 10:04:28+00:00                            NaN
# 1     2024-09-26 10:04:14+00:00                            NaN
# 2     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 3     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# 4     2024-09-25 07:51:20+00:00  photos\@ZemenExpress_5328.jpg
# ...                         ...                            ...
# 2632  2023-04-17 05:14:43+00:00  photos\@ZemenExpress_2598.jpg
# 2633  2023-04-15 12:04:23+00:00  photos\@ZemenExpress_2597.jpg
# 2634  2023-04-15 10:14:44+00:00  photos\@ZemenExpress_2596.jpg
# 2635  2023-04-15 10:14:11+00:00  photos\@ZemenExpress_2595.jpg
# 2636  2023-04-15 07:43:45+00:00                            NaN
#
# [2637 rows x 6 columns]

# %%
# Step 2: Drop empty rows (rows where all values are NaN)
df_cleaned = df.dropna(how='all')

# Step 3: Save the cleaned data back to a new CSV file (optional)
df_cleaned.to_csv('cleaned_telegram_data_zemen_express.csv', index=False)

# Optionally, view the first few rows of the cleaned dataframe
df_cleaned

# Step 4: Get the number of rows after dropping empty rows
cleaned_row_count = df_cleaned.shape[0]
print(f"Number of rows after dropping empty rows: {cleaned_row_count}")

# Step 5: Save the cleaned data back to a new CSV file (optional)
df_cleaned.to_csv('cleaned_telegram_data_zemen_express.csv', index=False)
df_cleaned
# Out:
# Number of rows after dropping empty rows: 2637
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5334
# 1     Zemen Express®    @ZemenExpress  5333
# 2     Zemen Express®    @ZemenExpress  5332
# 3     Zemen Express®    @ZemenExpress  5330
# 4     Zemen Express®    @ZemenExpress  5328
# ...              ...              ...   ...
# 2632  Zemen Express®    @ZemenExpress  2598
# 2633  Zemen Express®    @ZemenExpress  2597
# 2634  Zemen Express®    @ZemenExpress  2596
# 2635  Zemen Express®    @ZemenExpress  2595
# 2636  Zemen Express®    @ZemenExpress  2593
#
#                                                 Message  \
# 0     💥💥...................................💥💥\n\n🎯Ko...
# 1     💥💥...................................💥💥\n\n🎯Ko...
# 2     💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 3     💥💥...................................💥💥\n\n📌Si...
# 4                                                   NaN
# ...                                                 ...
# 2632  🎯 3pcs Stainless Steel Cake Shovel Cutter Knif...
# 2633  🎯3pcs Isolated Heat Pad \n🔰ሙቀትን መቋቋም የሚችል ትኩስ ...
# 2634  🎯 የእንጀራ እና የዳቦ ማቅረቢያ\n\nዋጋ፦  💰🏷  2500 ብር \n   ...
# 2635  🎯 Adjustable Base For Washing amachine & Refri...
# 2636  🎯 Adjustable Base For Washing amachine & Refri...
#
#                            Date                     Media Path
# 0     2024-09-26 10:04:28+00:00                            NaN
# 1     2024-09-26 10:04:14+00:00                            NaN
# 2     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 3     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# 4     2024-09-25 07:51:20+00:00  photos\@ZemenExpress_5328.jpg
# ...                         ...                            ...
# 2632  2023-04-17 05:14:43+00:00  photos\@ZemenExpress_2598.jpg
# 2633  2023-04-15 12:04:23+00:00  photos\@ZemenExpress_2597.jpg
# 2634  2023-04-15 10:14:44+00:00  photos\@ZemenExpress_2596.jpg
# 2635  2023-04-15 10:14:11+00:00  photos\@ZemenExpress_2595.jpg
# 2636  2023-04-15 07:43:45+00:00                            NaN
#
# [2637 rows x 6 columns]

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 651

# %%
df_clean = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
df_clean
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (1986, 6)
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5334
# 1     Zemen Express®    @ZemenExpress  5333
# 2     Zemen Express®    @ZemenExpress  5332
# 3     Zemen Express®    @ZemenExpress  5330
# 8     Zemen Express®    @ZemenExpress  5324
# ...              ...              ...   ...
# 2632  Zemen Express®    @ZemenExpress  2598
# 2633  Zemen Express®    @ZemenExpress  2597
# 2634  Zemen Express®    @ZemenExpress  2596
# 2635  Zemen Express®    @ZemenExpress  2595
# 2636  Zemen Express®    @ZemenExpress  2593
#
#                                                 Message  \
# 0     💥💥...................................💥💥\n\n🎯Ko...
# 1     💥💥...................................💥💥\n\n🎯Ko...
# 2     💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 3     💥💥...................................💥💥\n\n📌Si...
# 8     💥💥...................................💥💥\n\n📌Si...
# ...                                                 ...
# 2632  🎯 3pcs Stainless Steel Cake Shovel Cutter Knif...
# 2633  🎯3pcs Isolated Heat Pad \n🔰ሙቀትን መቋቋም የሚችል ትኩስ ...
# 2634  🎯 የእንጀራ እና የዳቦ ማቅረቢያ\n\nዋጋ፦  💰🏷  2500 ብር \n   ...
# 2635  🎯 Adjustable Base For Washing amachine & Refri...
# 2636  🎯 Adjustable Base For Washing amachine & Refri...
#
#                            Date                     Media Path
# 0     2024-09-26 10:04:28+00:00                            NaN
# 1     2024-09-26 10:04:14+00:00                            NaN
# 2     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 3     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# 8     2024-09-25 07:51:19+00:00  photos\@ZemenExpress_5324.jpg
# ...                         ...                            ...
# 2632  2023-04-17 05:14:43+00:00  photos\@ZemenExpress_2598.jpg
# 2633  2023-04-15 12:04:23+00:00  photos\@ZemenExpress_2597.jpg
# 2634  2023-04-15 10:14:44+00:00  photos\@ZemenExpress_2596.jpg
# 2635  2023-04-15 10:14:11+00:00  photos\@ZemenExpress_2595.jpg
# 2636  2023-04-15 07:43:45+00:00                            NaN
#
# [1986 rows x 6 columns]

# %%
message_df_clean=df_clean['Message']
message_df_clean
# Out:
# 0       💥💥...................................💥💥\n\n🎯Ko...
# 1       💥💥...................................💥💥\n\n🎯Ko...
# 2       💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 3       💥💥...................................💥💥\n\n📌Si...
# 8       💥💥...................................💥💥\n\n📌Si...
#                               ...
# 2632    🎯 3pcs Stainless Steel Cake Shovel Cutter Knif...
# 2633    🎯3pcs Isolated Heat Pad \n🔰ሙቀትን መቋቋም የሚችል ትኩስ ...
# 2634    🎯 የእንጀራ እና የዳቦ ማቅረቢያ\n\nዋጋ፦  💰🏷  2500 ብር \n   ...
# 2635    🎯 Adjustable Base For Washing amachine & Refri...
# 2636    🎯 Adjustable Base For Washing amachine & Refri...
# Name: Message, Length: 1986, dtype: object

# %%
# Example of your DataFrame
# df = pd.DataFrame({'Message': ['💥3pcs silicon brush spatulas...', '💥Mandoline Slicer...', ...]})

# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df_clean['Message'] = df_clean['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(df_clean.head())
# Out:
#     Channel Title Channel Username    ID  \
# 0  Zemen Express®    @ZemenExpress  5334
# 1  Zemen Express®    @ZemenExpress  5333
# 2  Zemen Express®    @ZemenExpress  5332
# 3  Zemen Express®    @ZemenExpress  5330
# 8  Zemen Express®    @ZemenExpress  5324
#
#                                              Message  \
# 0  ...................................\n\nKorean ...
# 1  ...................................\n\nKorean ...
# 2  ............. ................\n\nStainless St...
# 3  ...................................\n\nSimple ...
# 8  ...................................\n\nSilicon...
#
#                         Date                     Media Path
# 0  2024-09-26 10:04:28+00:00                            NaN
# 1  2024-09-26 10:04:14+00:00                            NaN
# 2  2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 3  2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# 8  2024-09-25 07:51:19+00:00  photos\@ZemenExpress_5324.jpg

# %%
df_clean.to_csv('../Data/cleaned_telegram_data_zemen_express.csv', index=False)
df_clean
# Out:
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5334
# 1     Zemen Express®    @ZemenExpress  5333
# 2     Zemen Express®    @ZemenExpress  5332
# 3     Zemen Express®    @ZemenExpress  5330
# 8     Zemen Express®    @ZemenExpress  5324
# ...              ...              ...   ...
# 2632  Zemen Express®    @ZemenExpress  2598
# 2633  Zemen Express®    @ZemenExpress  2597
# 2634  Zemen Express®    @ZemenExpress  2596
# 2635  Zemen Express®    @ZemenExpress  2595
# 2636  Zemen Express®    @ZemenExpress  2593
#
#                                                 Message  \
# 0     ...................................\n\nKorean ...
# 1     ...................................\n\nKorean ...
# 2     ............. ................\n\nStainless St...
# 3     ...................................\n\nSimple ...
# 8     ...................................\n\nSilicon...
# ...                                                 ...
# 2632   3pcs Stainless Steel Cake Shovel Cutter Knife...
# 2633  3pcs Isolated Heat Pad \nሙቀትን መቋቋም የሚችል ትኩስ ነገ...
# 2634   የእንጀራ እና የዳቦ ማቅረቢያ\n\nዋጋ፦    2500 ብር \n      ...
# 2635   Adjustable Base For Washing amachine & Refrig...
# 2636   Adjustable Base For Washing amachine & Refrig...
#
#                            Date                     Media Path
# 0     2024-09-26 10:04:28+00:00                            NaN
# 1     2024-09-26 10:04:14+00:00                            NaN
# 2     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 3     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# 8     2024-09-25 07:51:19+00:00  photos\@ZemenExpress_5324.jpg
# ...                         ...                            ...
# 2632  2023-04-17 05:14:43+00:00  photos\@ZemenExpress_2598.jpg
# 2633  2023-04-15 12:04:23+00:00  photos\@ZemenExpress_2597.jpg
# 2634  2023-04-15 10:14:44+00:00  photos\@ZemenExpress_2596.jpg
# 2635  2023-04-15 10:14:11+00:00  photos\@ZemenExpress_2595.jpg
# 2636  2023-04-15 07:43:45+00:00                            NaN
#
# [1986 rows x 6 columns]

# %%
import re

def label_message_utf8_with_birr(message):
    # Split the message at the first occurrence of '\n'
    if '\n' in message:
        first_line, remaining_message = message.split('\n', 1)
    else:
        first_line, remaining_message = message, ""
    
    labeled_tokens = []
    
    # Tokenize the first line
    first_line_tokens = re.findall(r'\S+', first_line)
    
    # Label the first token as B-PRODUCT and the rest as I-PRODUCT
    if first_line_tokens:
        labeled_tokens.append(f"{first_line_tokens[0]} B-PRODUCT")  # First token as B-PRODUCT
        for token in first_line_tokens[1:]:
            labeled_tokens.append(f"{token} I-PRODUCT")  # Remaining tokens as I-PRODUCT
    
    # Process the remaining message normally
    if remaining_message:
        lines = remaining_message.split('\n')
        for line in lines:
            tokens = re.findall(r'\S+', line)  # Tokenize each line while considering non-ASCII characters
            
            for token in tokens:
                # Check if token is a price (e.g., 500 ETB, $100, or ብር)
                if re.match(r'^\d{10,}$', token):
                    labeled_tokens.append(f"{token} O")  # Label as O for "other" or outside of any entity
                elif re.match(r'^\d+(\.\d{1,2})?$', token) or 'ETB' in token or 'ዋጋ' in token or '$' in token or 'ብር' in token:
                    labeled_tokens.append(f"{token} I-PRICE")
                # Check if token could be a location (e.g., cities or general location names)
                elif any(loc in token for loc in ['Addis Ababa', 'ለቡ', 'ለቡ መዳህኒዓለም', 'መገናኛ', 'ቦሌ', 'ሜክሲኮ']):
                    labeled_tokens.append(f"{token} I-LOC")
                # Assume other tokens are part of a product name or general text
                else:
                    labeled_tokens.append(f"{token} O")
    
    return "\n".join(labeled_tokens)

# Apply the updated function to the non-null messages
df_clean['Labeled_Message'] = df_clean['Message'].apply(label_message_utf8_with_birr)

# Display the updated DataFrame
df_clean.head()
# Out:
#     Channel Title Channel Username    ID  \
# 0  Zemen Express®    @ZemenExpress  5334
# 1  Zemen Express®    @ZemenExpress  5333
# 2  Zemen Express®    @ZemenExpress  5332
# 3  Zemen Express®    @ZemenExpress  5330
# 8  Zemen Express®    @ZemenExpress  5324
#
#                                              Message  \
# 0  ...................................\n\nKorean ...
# 1  ...................................\n\nKorean ...
# 2  ............. ................\n\nStainless St...
# 3  ...................................\n\nSimple ...
# 8  ...................................\n\nSilicon...
#
#                         Date                     Media Path  \
# 0  2024-09-26 10:04:28+00:00                            NaN
# 1  2024-09-26 10:04:14+00:00                            NaN
# 2  2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 3  2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# 8  2024-09-25 07:51:19+00:00  photos\@ZemenExpress_5324.jpg
#
#                                      Labeled_Message
# 0  ................................... B-PRODUCT\...
# 1  ................................... B-PRODUCT\...
# 2  ............. B-PRODUCT\n................ I-PR...
# 3  ................................... B-PRODUCT\...
# 8  ................................... B-PRODUCT\...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = 'labeled_telegram_product_price_location.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in df_clean.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")
