# %%
import pandas as pd
import pandas as pd
import re
import os
# Load your DataFrame
df = pd.read_csv('../Data/Zemen_Telegram_channal.csv')

# %%
df
# Out:
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5335
# 1     Zemen Express®    @ZemenExpress  5334
# 2     Zemen Express®    @ZemenExpress  5333
# 3     Zemen Express®    @ZemenExpress  5332
# 4     Zemen Express®    @ZemenExpress  5330
# ...              ...              ...   ...
# 4996  Zemen Express®    @ZemenExpress   120
# 4997  Zemen Express®    @ZemenExpress   115
# 4998  Zemen Express®    @ZemenExpress   114
# 4999  Zemen Express®    @ZemenExpress   113
# 5000  Zemen Express®    @ZemenExpress     1
#
#                                                 Message  \
# 0     👉ለመላው የክርስትና እምነት ተከታዮች በሙሉ እንኳን ለብርሃነ መስቀሉ በሰ...
# 1     💥💥...................................💥💥\n\n🎯Ko...
# 2     💥💥...................................💥💥\n\n🎯Ko...
# 3     💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 4     💥💥...................................💥💥\n\n📌Si...
# ...                                                 ...
# 4996  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4997  #ZemenExpress® is a platform that connect supp...
# 4998                   https://telegram.me/ZemenExpress
# 4999  #ZemenExpress® is a platform that connect supp...
# 5000                                                NaN
#
#                            Date                     Media Path
# 0     2024-09-27 07:09:36+00:00  photos\@ZemenExpress_5335.jpg
# 1     2024-09-26 10:04:28+00:00                            NaN
# 2     2024-09-26 10:04:14+00:00                            NaN
# 3     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 4     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# ...                         ...                            ...
# 4996  2020-04-24 16:15:34+00:00   photos\@ZemenExpress_120.jpg
# 4997  2020-04-24 09:32:43+00:00                            NaN
# 4998  2020-04-24 04:38:51+00:00                            NaN
# 4999  2020-04-23 17:58:01+00:00                            NaN
# 5000  2018-10-29 19:25:25+00:00                            NaN
#
# [5001 rows x 6 columns]

# %%
# Step 2: Drop empty rows (rows where all values are NaN)
df_cleaned = df.dropna(how='all')

# Step 3: Save the cleaned data back to a new CSV file (optional)
df_cleaned.to_csv('cleaned_telegram_data_zemen_express.csv', index=False)

# Optionally, view the first few rows of the cleaned dataframe
df_cleaned

# Step 4: Get the number of rows after dropping empty rows
cleaned_row_count = df_cleaned.shape[0]
print(f"Number of rows after dropping empty rows: {cleaned_row_count}")

# Step 5: Save the cleaned data back to a new CSV file (optional)
df_cleaned.to_csv('cleaned_telegram_data_zemen_express.csv', index=False)
df_cleaned
# Out:
# Number of rows after dropping empty rows: 5001
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5335
# 1     Zemen Express®    @ZemenExpress  5334
# 2     Zemen Express®    @ZemenExpress  5333
# 3     Zemen Express®    @ZemenExpress  5332
# 4     Zemen Express®    @ZemenExpress  5330
# ...              ...              ...   ...
# 4996  Zemen Express®    @ZemenExpress   120
# 4997  Zemen Express®    @ZemenExpress   115
# 4998  Zemen Express®    @ZemenExpress   114
# 4999  Zemen Express®    @ZemenExpress   113
# 5000  Zemen Express®    @ZemenExpress     1
#
#                                                 Message  \
# 0     👉ለመላው የክርስትና እምነት ተከታዮች በሙሉ እንኳን ለብርሃነ መስቀሉ በሰ...
# 1     💥💥...................................💥💥\n\n🎯Ko...
# 2     💥💥...................................💥💥\n\n🎯Ko...
# 3     💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 4     💥💥...................................💥💥\n\n📌Si...
# ...                                                 ...
# 4996  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4997  #ZemenExpress® is a platform that connect supp...
# 4998                   https://telegram.me/ZemenExpress
# 4999  #ZemenExpress® is a platform that connect supp...
# 5000                                                NaN
#
#                            Date                     Media Path
# 0     2024-09-27 07:09:36+00:00  photos\@ZemenExpress_5335.jpg
# 1     2024-09-26 10:04:28+00:00                            NaN
# 2     2024-09-26 10:04:14+00:00                            NaN
# 3     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 4     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# ...                         ...                            ...
# 4996  2020-04-24 16:15:34+00:00   photos\@ZemenExpress_120.jpg
# 4997  2020-04-24 09:32:43+00:00                            NaN
# 4998  2020-04-24 04:38:51+00:00                            NaN
# 4999  2020-04-23 17:58:01+00:00                            NaN
# 5000  2018-10-29 19:25:25+00:00                            NaN
#
# [5001 rows x 6 columns]

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 956

# %%
df_clean = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
df_clean
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (5001, 6)
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5335
# 1     Zemen Express®    @ZemenExpress  5334
# 2     Zemen Express®    @ZemenExpress  5333
# 3     Zemen Express®    @ZemenExpress  5332
# 4     Zemen Express®    @ZemenExpress  5330
# ...              ...              ...   ...
# 4995  Zemen Express®    @ZemenExpress   121
# 4996  Zemen Express®    @ZemenExpress   120
# 4997  Zemen Express®    @ZemenExpress   115
# 4998  Zemen Express®    @ZemenExpress   114
# 4999  Zemen Express®    @ZemenExpress   113
#
#                                                 Message  \
# 0     👉ለመላው የክርስትና እምነት ተከታዮች በሙሉ እንኳን ለብርሃነ መስቀሉ በሰ...
# 1     💥💥...................................💥💥\n\n🎯Ko...
# 2     💥💥...................................💥💥\n\n🎯Ko...
# 3     💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 4     💥💥...................................💥💥\n\n📌Si...
# ...                                                 ...
# 4995  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4996  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4997  #ZemenExpress® is a platform that connect supp...
# 4998                   https://telegram.me/ZemenExpress
# 4999  #ZemenExpress® is a platform that connect supp...
#
#                            Date                     Media Path
# 0     2024-09-27 07:09:36+00:00  photos\@ZemenExpress_5335.jpg
# 1     2024-09-26 10:04:28+00:00                            NaN
# 2     2024-09-26 10:04:14+00:00                            NaN
# 3     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 4     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# ...                         ...                            ...
# 4995  2020-04-24 16:52:40+00:00                            NaN
# 4996  2020-04-24 16:15:34+00:00   photos\@ZemenExpress_120.jpg
# 4997  2020-04-24 09:32:43+00:00                            NaN
# 4998  2020-04-24 04:38:51+00:00                            NaN
# 4999  2020-04-23 17:58:01+00:00                            NaN
#
# [4045 rows x 6 columns]

# %%
message_df_clean=df_clean['Message']
message_df_clean
# Out:
# 0       👉ለመላው የክርስትና እምነት ተከታዮች በሙሉ እንኳን ለብርሃነ መስቀሉ በሰ...
# 1       💥💥...................................💥💥\n\n🎯Ko...
# 2       💥💥...................................💥💥\n\n🎯Ko...
# 3       💥💥.............👡 👟................💥💥\n\n🎯Stain...
# 4       💥💥...................................💥💥\n\n📌Si...
#                               ...
# 4995    ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4996    ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4997    #ZemenExpress® is a platform that connect supp...
# 4998                     https://telegram.me/ZemenExpress
# 4999    #ZemenExpress® is a platform that connect supp...
# Name: Message, Length: 4045, dtype: object

# %%
# Example of your DataFrame
# df = pd.DataFrame({'Message': ['💥3pcs silicon brush spatulas...', '💥Mandoline Slicer...', ...]})

# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df_clean['Message'] = df_clean['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(df_clean.head())
# Out:
#     Channel Title Channel Username    ID  \
# 0  Zemen Express®    @ZemenExpress  5335
# 1  Zemen Express®    @ZemenExpress  5334
# 2  Zemen Express®    @ZemenExpress  5333
# 3  Zemen Express®    @ZemenExpress  5332
# 4  Zemen Express®    @ZemenExpress  5330
#
#                                              Message  \
# 0  ለመላው የክርስትና እምነት ተከታዮች በሙሉ እንኳን ለብርሃነ መስቀሉ በሰላ...
# 1  ...................................\n\nKorean ...
# 2  ...................................\n\nKorean ...
# 3  ............. ................\n\nStainless St...
# 4  ...................................\n\nSimple ...
#
#                         Date                     Media Path
# 0  2024-09-27 07:09:36+00:00  photos\@ZemenExpress_5335.jpg
# 1  2024-09-26 10:04:28+00:00                            NaN
# 2  2024-09-26 10:04:14+00:00                            NaN
# 3  2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 4  2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# C:\Users\Addisu\AppData\Local\Temp\ipykernel_32788\1104882285.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Message'] = df_clean['Message'].apply(remove_emojis)

# %%
df_clean.to_csv('../Data/cleaned_telegram_5000_zemen_express.csv', index=False)
df_clean
# Out:
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  5335
# 1     Zemen Express®    @ZemenExpress  5334
# 2     Zemen Express®    @ZemenExpress  5333
# 3     Zemen Express®    @ZemenExpress  5332
# 4     Zemen Express®    @ZemenExpress  5330
# ...              ...              ...   ...
# 4995  Zemen Express®    @ZemenExpress   121
# 4996  Zemen Express®    @ZemenExpress   120
# 4997  Zemen Express®    @ZemenExpress   115
# 4998  Zemen Express®    @ZemenExpress   114
# 4999  Zemen Express®    @ZemenExpress   113
#
#                                                 Message  \
# 0     ለመላው የክርስትና እምነት ተከታዮች በሙሉ እንኳን ለብርሃነ መስቀሉ በሰላ...
# 1     ...................................\n\nKorean ...
# 2     ...................................\n\nKorean ...
# 3     ............. ................\n\nStainless St...
# 4     ...................................\n\nSimple ...
# ...                                                 ...
# 4995  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4996  ከውኃ ማሰሮ ( Jar ) ላይ የመጠጥ ዉሃ የሚስብ ተንቀሳቃሽ እና (በኤሌ...
# 4997  #ZemenExpress® is a platform that connect supp...
# 4998                   https://telegram.me/ZemenExpress
# 4999  #ZemenExpress® is a platform that connect supp...
#
#                            Date                     Media Path
# 0     2024-09-27 07:09:36+00:00  photos\@ZemenExpress_5335.jpg
# 1     2024-09-26 10:04:28+00:00                            NaN
# 2     2024-09-26 10:04:14+00:00                            NaN
# 3     2024-09-26 07:19:17+00:00  photos\@ZemenExpress_5332.jpg
# 4     2024-09-25 18:40:01+00:00  photos\@ZemenExpress_5330.jpg
# ...                         ...                            ...
# 4995  2020-04-24 16:52:40+00:00                            NaN
# 4996  2020-04-24 16:15:34+00:00   photos\@ZemenExpress_120.jpg
# 4997  2020-04-24 09:32:43+00:00                            NaN
# 4998  2020-04-24 04:38:51+00:00                            NaN
# 4999  2020-04-23 17:58:01+00:00                            NaN
#
# [4045 rows x 6 columns]
